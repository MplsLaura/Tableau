# %%
import pandas as pd

# %%
file_one = "201306-citibike-tripdata.csv"
file_two = "202206-citbike-tripdata.csv"

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")
# Out:
# C:\Users\lwmur\AppData\Local\Temp\ipykernel_30628\2142207737.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")

# %%
file_one_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
file_two_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  FD85DE523427365B  classic_bike  2022-06-08 18:55:00  2022-06-08 18:58:13
# 1  E1DF44B06B360036  classic_bike  2022-06-18 16:34:50  2022-06-18 16:47:49
# 2  72B6DBF42BC1F9E1  classic_bike  2022-06-11 17:57:00  2022-06-11 18:07:33
# 3  5FABA5CB97A6EA64  classic_bike  2022-06-23 17:32:04  2022-06-23 17:38:36
# 4  EBA54764AA1A3A41  classic_bike  2022-06-30 16:17:43  2022-06-30 16:27:58
#
#        start_station_name start_station_id          end_station_name  \
# 0     E 149 St & Park Ave          7884.04     Morris Ave & E 153 St
# 1  E 115 St & Madison Ave          7599.02  W 148 St & Amsterdam Ave
# 2  E 115 St & Madison Ave          7599.02           2 Ave & E 99 St
# 3  W Broadway & Spring St          5569.06    N Moore St & Hudson St
# 4         E 14 St & 1 Ave           5779.1           5 Ave & E 29 St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
file_one_df
# Out:
#         tripduration            starttime             stoptime  \
# 0                695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2               2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4               1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...              ...                  ...                  ...
# 577698           925  2013-06-30 23:59:27  2013-07-01 00:14:52
# 577699           279  2013-06-30 23:59:36  2013-07-01 00:04:15
# 577700           161  2013-06-30 23:59:33  2013-07-01 00:02:14
# 577701           909  2013-06-30 23:59:47  2013-07-01 00:14:56
# 577702           634  2013-07-01 00:00:00  2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# ...

# %%
file_two_df
# Out:
#                   ride_id rideable_type           started_at  \
# 0        FD85DE523427365B  classic_bike  2022-06-08 18:55:00
# 1        E1DF44B06B360036  classic_bike  2022-06-18 16:34:50
# 2        72B6DBF42BC1F9E1  classic_bike  2022-06-11 17:57:00
# 3        5FABA5CB97A6EA64  classic_bike  2022-06-23 17:32:04
# 4        EBA54764AA1A3A41  classic_bike  2022-06-30 16:17:43
# ...                   ...           ...                  ...
# 3432878  52758C21D58728B4  classic_bike  2022-06-25 00:45:19
# 3432879  2F2B099B77266BF2  classic_bike  2022-06-21 16:52:08
# 3432880  AEE172A41A2FDA65  classic_bike  2022-06-29 17:58:20
# 3432881  3E6A2E15FD49F94E  classic_bike  2022-06-16 19:31:34
# 3432882  EA18E4BF86FD46F8  classic_bike  2022-06-16 12:15:02
#
#                     ended_at        start_station_name start_station_id  \
# 0        2022-06-08 18:58:13       E 149 St & Park Ave          7884.04
# 1        2022-06-18 16:47:49    E 115 St & Madison Ave          7599.02
# ...

# %%
file_one_df.count()
# Out:
# tripduration               577703
# starttime                  577703
# stoptime                   577703
# start station id           577703
# start station name         577703
# start station latitude     577703
# start station longitude    577703
# end station id             559644
# end station name           559644
# end station latitude       559644
# end station longitude      559644
# bikeid                     577703
# usertype                   577703
# birth year                 337382
# gender                     577703
# dtype: int64

# %%
clean_file = file_one_df.dropna(how='any')

# %%
clean_file_two = file_two_df.dropna(how='any')

# %%
clean_file.count()
# Out:
# tripduration               326841
# starttime                  326841
# stoptime                   326841
# start station id           326841
# start station name         326841
# start station latitude     326841
# start station longitude    326841
# end station id             326841
# end station name           326841
# end station latitude       326841
# end station longitude      326841
# bikeid                     326841
# usertype                   326841
# birth year                 326841
# gender                     326841
# dtype: int64

# %%
clean_file_two.count()
# Out:
# ride_id               3426527
# rideable_type         3426527
# started_at            3426527
# ended_at              3426527
# start_station_name    3426527
# start_station_id      3426527
# end_station_name      3426527
# end_station_id        3426527
# start_lat             3426527
# start_lng             3426527
# end_lat               3426527
# end_lng               3426527
# member_casual         3426527
# dtype: int64

# %%
stations_detes = clean_file_two.groupby(clean_file_two['start_station_id']).first()

# %%
print (stations_detes['start_lat'])
# Out:
# start_station_id
# 2733.03      40.633385
# 2782.02      40.635679
# 2832.03      40.637033
# 2872.02      40.637660
# 2883.03      40.638246
#                ...
# 8841.03      40.882083
# Lab - NYC    40.754166
# SYS016       40.709667
# SYS032       40.709581
# SYS038       40.709306
# Name: start_lat, Length: 3110, dtype: float64

# %%
clean_file.to_csv('file_one.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30628\2985235955.py in <module>
# ----> 1 clean_file.to_csv('file_one.csv', encoding='utf-8')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
stations_detes.to_csv('stations_two.csv', encoding='utf-8')
