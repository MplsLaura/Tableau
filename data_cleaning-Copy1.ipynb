# %%
import pandas as pd

# %%
file_three = "201506-citibike-tripdata.csv"

# %%
file_three_df = pd.read_csv(file_three, encoding="ISO-8859-1")

# %%
file_three_df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# ...

# %%
file_three_df
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0               1338    6/1/2015 0:00  6/1/2015 0:22               128
# 1                290    6/1/2015 0:00  6/1/2015 0:05               438
# 2                634    6/1/2015 0:01  6/1/2015 0:11               383
# 3                159    6/1/2015 0:01  6/1/2015 0:04               361
# 4               1233    6/1/2015 0:02  6/1/2015 0:22               382
# ...              ...              ...            ...               ...
# 941214          1053  6/30/2015 23:59  7/1/2015 0:17               323
# 941215          1149  6/30/2015 23:59  7/1/2015 0:18               116
# 941216          3557  6/30/2015 23:59  7/1/2015 0:58               454
# 941217           819  6/30/2015 23:59  7/1/2015 0:13               410
# 941218           667  6/30/2015 23:59  7/1/2015 0:10               308
#
#                  start station name  start station latitude  \
# ...

# %%
file_three_df.count()
# Out:
# tripduration               941219
# starttime                  941219
# stoptime                   941219
# start station id           941219
# start station name         941219
# start station latitude     941219
# start station longitude    941219
# end station id             941219
# end station name           941219
# end station latitude       941219
# end station longitude      941219
# bikeid                     941219
# usertype                   941219
# birth year                 810827
# gender                     941219
# dtype: int64

# %%
clean_file_three = file_three_df.dropna(how='any')

# %%
clean_file_three.count()
# Out:
# tripduration               810827
# starttime                  810827
# stoptime                   810827
# start station id           810827
# start station name         810827
# start station latitude     810827
# start station longitude    810827
# end station id             810827
# end station name           810827
# end station latitude       810827
# end station longitude      810827
# bikeid                     810827
# usertype                   810827
# birth year                 810827
# gender                     810827
# dtype: int64

# %%
clean_file_three.to_csv('file_three.csv', encoding='utf-8')
